# %%
# Installing libraries and dependencies
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('./expenses2.csv')

# %%
data.head()
# Out:
#    Amount       vendor         date   description      category Location
# 0   60.96  waw-airport  19.09.2018.          food     groceries   poland
# 1  420.00         dorm  20.09.2018.  accomodation  accomodation   poland
# 2  660.00         dorm  20.09.2018.  accomodation  accomodation   poland
# 3   13.99       bistro  21.09.2018.          food     groceries   poland
# 4   14.89    biedronka  21.09.2018.          food     groceries   poland

# %%
data.tail()
# Out:
#      Amount       vendor         date  description    category Location
# 165    10.0       konzum   24.12.2018         food   groceries   sweden
# 166   100.0          ina   27.12.2018          gas         car   sweden
# 167   120.0  ice-skating   27.12.2018  ice-skating  activities   sweden
# 168   200.0          ina   27.12.2018          gas         car  germany
# 169    12.0  coffee-shop  06.01.2019.       coffee  activities   poland

# %%
data.columns
# Out:
# Index(['Amount', 'vendor', 'date', 'description', 'category', 'Location'], dtype='object')

# %%
data.shape
# Out:
# (170, 6)

# %%
data.describe()
# Out:
#            Amount
# count  170.000000
# mean    78.574353
# std    122.916469
# min      2.100000
# 25%     16.625000
# 50%     35.950000
# 75%     75.000000
# max    665.000000

# %%
data.isnull().sum()
# Out:
# Amount         0
# vendor         0
# date           0
# description    0
# category       0
# Location       0
# dtype: int64

# %%
#visualization

# %%
sns.relplot(x='Amount', y='vendor', data=data)

# %%
sns.relplot(x='Amount', y='Location', data=data)

# %%
sns.relplot(x='Amount', y='category', data=data)

# %%
sns.relplot(x='Amount', y='date', data=data)

# %%
sns.relplot(x='Amount', y='description', data=data)

# %%
#model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = data.drop(['Amount'], axis = 1)
test = data['Amount']
